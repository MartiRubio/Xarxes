# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#data
zero = [-9,-8,-8,-6,-9,-7,-8,-9,-21,-9,-8,-8,-8,-10,-9,-9,-9,-9,-8,-8]
mig = [-34,-34,-30,-32,-29,-30,-34,-30,-31,-33,-30,-32,-30,-26,-30,-34,-31,-30,-32,-33]
un = [-35,-37,-38,-42,-41,-40,-42,-42,-42,-43,-41,-44,-38,-39,-38,-38,-40,-38,-40,-41]
dos = [-44,-45,-46,-41,-43,-48,-41,-48,-51,-51,-44,-48,-49,-47,-45,-49,-46,-51,-52,-51]
tres = [-52,-50,-66,-65,-62,-57,-50,-48,-49,-45,-47,-55,-53,-51,-47,-49,-47,-47,-47,-46]
quatre = [-50,-53,-57,-51,-57,-55,-64,-61,-69,-67,-57,-68,-57,-59,-69,-72,-69,-65,-65,-66]
set_ = [-72,-60,-60,-62,-61,-60,-63,-70,-63,-63,-71,-70,-69,-67,-65,-65,-71,-69,-61,-57]
deu = [np.nan,-84,-85,-83,-89,-80,np.nan,-84,-80,-81,-89,-93,np.nan,np.nan,-87,-88,-85,-85,-86,np.nan]
quinze = [-79,-77,-79,-76,-79,np.nan,-84,-80,-80,-82,-81,np.nan,-82,-85,-79,-79,-84,-84,-80,-74]

# %%
zero = pd.DataFrame(data=zero, columns=['dB'])
half = pd.DataFrame(data=mig, columns=['dB'])
one = pd.DataFrame(data=un, columns=['dB'])
two = pd.DataFrame(data=dos, columns=['dB'])
three = pd.DataFrame(data=tres, columns=['dB'])
four = pd.DataFrame(data=quatre, columns=['dB'])
seven = pd.DataFrame(data=set_, columns=['dB'])
ten = pd.DataFrame(data=deu, columns=['dB'])
fteen = pd.DataFrame(data=quinze, columns=['dB'])

zero['distance'] = 0
half['distance'] = 0.5
one['distance'] = 1
two['distance'] = 2
three['distance'] = 3
four['distance'] = 4
seven['distance'] = 7
ten['distance'] = 10
fteen['distance'] = 15

total = pd.concat([zero, half, one, two, three, four, seven, ten, fteen])
total.index=[i for i in range(1, len(total) + 1)]
total
# Out:
#        dB  distance
# 1    -9.0       0.0
# 2    -8.0       0.0
# 3    -8.0       0.0
# 4    -6.0       0.0
# 5    -9.0       0.0
# 6    -7.0       0.0
# 7    -8.0       0.0
# 8    -9.0       0.0
# 9   -21.0       0.0
# 10   -9.0       0.0
# 11   -8.0       0.0
# 12   -8.0       0.0
# 13   -8.0       0.0
# 14  -10.0       0.0
# 15   -9.0       0.0
# 16   -9.0       0.0
# 17   -9.0       0.0
# 18   -9.0       0.0
# 19   -8.0       0.0
# 20   -8.0       0.0
# 21  -34.0       0.5
# 22  -34.0       0.5
# 23  -30.0       0.5
# 24  -32.0       0.5
# 25  -29.0       0.5
# 26  -30.0       0.5
# 27  -34.0       0.5
# 28  -30.0       0.5
# 29  -31.0       0.5
# 30  -33.0       0.5
# ..    ...       ...
# 151 -89.0      10.0
# 152 -93.0      10.0
# 153   NaN      10.0
# 154   NaN      10.0
# 155 -87.0      10.0
# 156 -88.0      10.0
# 157 -85.0      10.0
# 158 -85.0      10.0
# 159 -86.0      10.0
# 160   NaN      10.0
# 161 -79.0      15.0
# 162 -77.0      15.0
# 163 -79.0      15.0
# ...

# %%
plt.scatter(total['dB'], total['distance'])

# %%
group = total.groupby(by='distance').mean()

# %%
group['eta'] = [1, 0.911, 1, 1.02, 1.04, 1.19, 1.14, 1.41, np.nan]

# %%
group[]
# Out:
#                  dB    eta
# distance
# 0.0       -9.000000  1.000
# 0.5      -31.250000  0.911
# 1.0      -39.950000  1.000
# 2.0      -47.000000  1.020
# 3.0      -51.650000  1.040
# 4.0      -61.550000  1.190
# 7.0      -64.950000  1.140
# 10.0     -85.266667  1.410
# 15.0     -80.222222    NaN

# %%
plt.scatter(group['eta'], group.index.values)
