# %%
#data
one_meter = [-52, -50, -51, -54, -54, 
             -56, -54, -54, -54, -52,
             -55, -53, -54, -52, -51, 
             -54, -58, -61, -56, -55]

two_meters = [-56, -59, -57, -57, -61, 
              -61, -55, -57, -59, -59,
              -60, -62, -62, -56]

three_meters = [-61, -70, -65, -74, -71,
                -64, -61, -70, -63, -74,
                -61, -67, -67, -64, -62,
                -65, -70, -60, -64, -65]

four_meters = [-71, -63, -72, -73, -71, 
               -78, -68, -72, -68, -69, 
               -64, -68]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.hist(one_meter)
plt.show()
plt.hist(two_meters)
plt.show()
plt.hist(three_meters)
plt.show()
plt.hist(four_meters)
plt.show()

# %%
one = pd.DataFrame(data=one_meter, columns=['dB'])
two = pd.DataFrame(data=two_meters, columns=['dB'])
three = pd.DataFrame(data=three_meters, columns=['dB'])
four = pd.DataFrame(data=four_meters, columns=['dB'])
one['distance'] = 1
two['distance'] = 2
three['distance'] = 3
four['distance'] = 4
total = pd.concat([one, two, three, four])
total.index=[i for i in range(1, len(total) + 1)]
total
# Out:
#     dB  distance
# 1  -52         1
# 2  -50         1
# 3  -51         1
# 4  -54         1
# 5  -54         1
# 6  -56         1
# 7  -54         1
# 8  -54         1
# 9  -54         1
# 10 -52         1
# 11 -55         1
# 12 -53         1
# 13 -54         1
# 14 -52         1
# 15 -51         1
# 16 -54         1
# 17 -58         1
# 18 -61         1
# 19 -56         1
# 20 -55         1
# 21 -56         2
# 22 -59         2
# 23 -57         2
# 24 -57         2
# 25 -61         2
# 26 -61         2
# 27 -55         2
# 28 -57         2
# 29 -59         2
# 30 -59         2
# ..  ..       ...
# 37 -65         3
# 38 -74         3
# 39 -71         3
# 40 -64         3
# 41 -61         3
# 42 -70         3
# 43 -63         3
# 44 -74         3
# 45 -61         3
# 46 -67         3
# 47 -67         3
# 48 -64         3
# 49 -62         3
# 50 -65         3
# 51 -70         3
# 52 -60         3
# 53 -64         3
# 54 -65         3
# 55 -71         4
# 56 -63         4
# 57 -72         4
# 58 -73         4
# 59 -71         4
# 60 -78         4
# 61 -68         4
# 62 -72         4
# 63 -68         4
# 64 -69         4
# 65 -64         4
# 66 -68         4
#
# [66 rows x 2 columns]

# %%
plt.hist(total[total['distance'] == 1], color="red")
plt.hist(total[total['distance'] == 2], color="red")
plt.hist(total[total['distance'] == 3], color="red")
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0f4b9c8d9f51> in <module>()
# ----> 1 plt.hist(total[total['distance'] == 1], color="red")
#       2 plt.hist(total[total['distance'] == 2])
#       3 plt.hist(total[total['distance'] == 3])
#       4 plt.hist(total[total['distance'] == 4])
#       5 plt.show()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6502             color = mcolors.to_rgba_array(color)
#    6503             if len(color) != nx:
# -> 6504                 raise ValueError("color kwarg must have one color per dataset")
#    6505
#    6506         # If bins are not specified either explicitly or via range,
#
# ValueError: color kwarg must have one color per dataset
